# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from matplotlib.lines import Line2D

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %%
#Creating a dataframe to store the data
weatherData = pd.DataFrame({'City': cities})

# %% [markdown]
# # Perform API Calls

# %%
#Intializing the start of the API call
print("Beginnign Data Retrieval")

#Setting counter
recordNumber = 1
setNumber = 1

#Running a loop over cities list
for index, row in weatherData.iterrows():
    
    #Getting the city name
    cityName = row['City']
    
    #Generating the URL
    url = f'http://api.openweathermap.org/data/2.5/weather?q={cityName}&APPID={api_key}&units=imperial'
    
    #Checking for any missing data
    try:
        #Making the API call
        data = requests.get(url).json()
        
        print(f'Processing Record {recordNumber} of Set {setNumber} | {cityName}')
        
        #Storing data directly in the dataframe
        weatherData.loc[index, 'Cloudiness'] = data['clouds']['all']
        weatherData.loc[index, 'Country'] = data['sys']['country']
        weatherData.loc[index, 'Date'] = data['dt']
        weatherData.loc[index, 'Humidity'] = data['main']['humidity']
        weatherData.loc[index, 'Lat'] = data['coord']['lat']
        weatherData.loc[index, 'Lng'] = data['coord']['lon']
        weatherData.loc[index, 'Max Temp'] = data['main']['temp_max']
        weatherData.loc[index, 'Wind Speed'] = data['wind']['speed']
        
        if(recordNumber == 50):
            recordNumber = 1
            setNumber += 1
        else:
            recordNumber += 1
    except:
        print('City not found. Skipping...')
# Out:
# Beginnign Data Retrieval
# Processing Record 1 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | bandar-e lengeh
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | kruisfontein
# Processing Record 5 of Set 1 | lavrentiya
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | husavik
# Processing Record 8 of Set 1 | lagoa
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | gweta
# Processing Record 11 of Set 1 | lorengau
# Processing Record 12 of Set 1 | daru
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | carutapera
# Processing Record 15 of Set 1 | oranjestad
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | acajutla
# Processing Record 18 of Set 1 | vao
# Processing Record 19 of Set 1 | ostrovnoy
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | turbat
# Processing Record 23 of Set 1 | tuktoyaktuk
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | zeya
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | bengkulu
# City not found. Skipping...
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | pauini
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | high rock
# Processing Record 31 of Set 1 | gazojak
# Processing Record 32 of Set 1 | dudinka
# Processing Record 33 of Set 1 | sun city west
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | san quintin
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | san patricio
# Processing Record 38 of Set 1 | boa vista
# Processing Record 39 of Set 1 | pisco
# Processing Record 40 of Set 1 | ganzhou
# Processing Record 41 of Set 1 | mountain home
# Processing Record 42 of Set 1 | sioux lookout
# Processing Record 43 of Set 1 | green valley
# Processing Record 44 of Set 1 | casa grande
# Processing Record 45 of Set 1 | noumea
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | walvis bay
# Processing Record 48 of Set 1 | vila franca do campo
# Processing Record 49 of Set 1 | avera
# Processing Record 50 of Set 1 | mount isa
# Processing Record 1 of Set 2 | qui nhon
# City not found. Skipping...
# Processing Record 1 of Set 2 | cabo san lucas
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 
of Set 4 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 43 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 4 | faya
# Processing Record 44 of Set 4 | port alfred
# Processing Record 45 of Set 4 | aden
# Processing Record 46 of Set 4 | maraa
# Processing Record 47 of Set 4 | dharmabad
# Processing Record 48 of Set 4 | taltal
# Processing Record 49 of Set 4 | kaitangata
# Processing Record 50 of Set 4 | kavieng
# Processing Record 1 of Set 5 | faanui
# Processing Record 2 of Set 5 | kassala
# Processing Record 3 of Set 5 | jaque
# City not found. Skipping...
# Processing Record 3 of Set 5 | bandarbeyla
# Processing Record 4 of Set 5 | chernyshevskiy
# Processing Record 5 of Set 5 | emilio carranza
# Processing Record 6 of Set 5 | ribeira grande
# Processing Record 7 of Set 5 | lompoc
# Processing Record 8 of Set 5 | narsaq
# Processing Record 9 of Set 5 | matay
# Processing Record 10 of Set 5 | morgan city
# Processing Record 11 of Set 5 | saint-philippe
# Processing Record 12 of Set 5 | tura
# Processing Record 13 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 5 | berlevag
# Processing Record 14 of Set 5 | bischofswerda
# Processing Record 15 of Set 5 | havoysund
# Processing Record 16 of Set 5 | demba
# Processing Record 17 of Set 5 | ahome
# Processing Record 18 of Set 5 | oranjemund
# Processing Record 19 of Set 5 | mana
# Processing Record 20 of Set 5 | prainha
# Processing Record 21 of Set 5 | santa cruz
# Processing Record 22 of Set 5 | port elizabeth
# Processing Record 23 of Set 5 | nuuk
# Processing Record 24 of Set 5 | birao
# Processing Record 25 of Set 5 | seymchan
# Processing Record 26 of Set 5 | carnarvon
# Processing Record 27 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 5 | bowen
# Processing Record 28 of Set 5 | cidreira
# Processing Record 29 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 5 | adrar
# Processing Record 30 of Set 5 | moanda
# Processing Record 31 of Set 5 | ancud
# Processing Record 32 of Set 5 | puerto leguizamo
# Processing Record 33 of Set 5 | victor harbor
# Processing Record 34 of Set 5 | yankton
# Processing Record 35 of Set 5 | pangai
# Processing Record 36 of Set 5 | altamira
# Processing Record 37 of Set 5 | yumen
# Processing Record 38 of Set 5 | along
# Processing Record 39 of Set 5 | kundla
# Processing Record 40 of Set 5 | bana
# Processing Record 41 of Set 5 | emirdag
# Processing Record 42 of Set 5 | ruteng
# Processing Record 43 of Set 5 | sola
# Processing Record 44 of Set 5 | beisfjord
# Processing Record 45 of Set 5 | mackay
# Processing Record 46 of Set 5 | ambon
# Processing Record 47 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 47 of Set 5 | obo
# Processing Record 48 of Set 5 | airai
# Processing Record 49 of Set 5 | curup
# Processing Record 50 of Set 5 | asau
# City not found. Skipping...
# Processing Record 50 of Set 5 | mali
# Processing Record 1 of Set 6 | hamilton
# Processing Record 2 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 6 | mayo
# Processing Record 3 of Set 6 | klaksvik
# Processing Record 4 of Set 6 | kirakira
# Processing Record 5 of Set 6 | inhambane
# Processing Record 6 of Set 6 | fairbanks
# Processing Record 7 of Set 6 | bonavista
# Processing Record 8 of Set 6 | gubkinskiy
# Processing Record 9 of Set 6 | shelburne
# Processing Record 10 of Set 6 | los llanos de aridane
# Processing Record 11 of Set 6 | ceres
# Processing Record 12 of Set 6 | yeppoon
# Processing Record 13 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 6 | duldurga
# Processing Record 14 of Set 6 | porbandar
# Processing Record 15 of Set 6 | hofn
# Processing Record 16 of Set 6 | warangal
# Processing Record 17 of Set 6 | batemans bay
# Processing Record 18 of Set 6 | ust-nera
# Processing Record 19 of Set 6 | acapulco
# Processing Record 20 of Set 6 | diffa
# Processing Record 21 of Set 6 | padang
# Processing Record 22 of Set 6 | saint anthony
# Processing Record 23 of Set 6 | bam
# Processing Record 24 of Set 6 | chapais
# Processing Record 25 of Set 6 | beidao
# Processing Record 26 of Set 6 | szczytno
# Processing Record 27 of Set 6 | champerico
# Processing Record 28 of Set 6 | burgersdorp
# Processing Record 29 of Set 6 | kidal
# Processing Record 30 of Set 6 | abonnema
# Processing Record 31 of Set 6 | bambanglipuro
# Processing Record 32 of Set 6 | ahumada
# City not found. Skipping...
# Processing Record 32 of Set 6 | dukat
# Processing Record 33 of Set 6 | washougal
# Processing Record 34 of Set 6 | waitati
# Processing Record 35 of Set 6 | port hardy
# Processing Record 36 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 6 | buritizeiro
# Processing Record 37 of Set 6 | price
# Processing Record 38 of Set 6 | malko tarnovo
# Processing Record 39 of Set 6 | egvekinot
# Processing Record 40 of Set 6 | ilulissat
# Processing Record 41 of Set 6 | san policarpo
# Processing Record 42 of Set 6 | scarborough
# Processing Record 43 of Set 6 | cayenne
# Processing Record 44 of Set 6 | sosnovo-ozerskoye
# Processing Record 45 of Set 6 | fort nelson
# Processing Record 46 of Set 6 | roma
# Processing Record 47 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 6 | dharchula
# Processing Record 48 of Set 6 | ludvika
# Processing Record 49 of Set 6 | kiama
# Processing Record 50 of Set 6 | qaqortoq
# Processing Record 1 of Set 7 | dwarka
# Processing Record 2 of Set 7 | ballina
# Processing Record 3 of Set 7 | poya
# Processing Record 4 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 4 of Set 7 | mende
# Processing Record 5 of Set 7 | enkoping
# Processing Record 6 of Set 7 | erenhot
# Processing Record 7 of Set 7 | luderitz
# Processing Record 8 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 8 of Set 7 | bathsheba
# Processing Record 9 of Set 7 | hungund
# Processing Record 10 of Set 7 | norman wells
# Processing Record 11 of Set 7 | kholodnyy
# Processing Record 12 of Set 7 | maridi
# City not found. Skipping...
# Processing Record 12 of Set 7 | karratha
# Processing Record 13 of Set 7 | hay river
# Processing Record 14 of Set 7 | kieta
# Processing Record 15 of Set 7 | ushumun
# Processing Record 16 of Set 7 | veraval
# Processing Record 17 of Set 7 | nacala
# Processing Record 18 of Set 7 | vanimo
# Processing Record 19 of Set 7 | hami
# Processing Record 20 of Set 7 | puerto escondido
# Processing Record 21 of Set 7 | jinchang
# Processing Record 22 of Set 7 | codrington
# Processing Record 23 of Set 7 | dingle
# Processing Record 24 of Set 7 | berbera
# City not found. Skipping...
# Processing Record 24 of Set 7 | qaanaaq
# Processing Record 25 of Set 7 | camacha
# Processing Record 26 of Set 7 | pirovskoye
# Processing Record 27 of Set 7 | meybod
# Processing Record 28 of Set 7 | kodiak
# Processing Record 29 of Set 7 | bainbridge
# Processing Record 30 of Set 7 | bambous virieux
# Processing Record 31 of Set 7 | port-de-paix
# City not found. Skipping...
# Processing Record 31 of Set 7 | sept-iles
# Processing Record 32 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record
of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 9 | margate
# Processing Record 2 of Set 9 | urucara
# Processing Record 3 of Set 9 | bubaque
# Processing Record 4 of Set 9 | arvika
# Processing Record 5 of Set 9 | duma
# Processing Record 6 of Set 9 | sneek
# Processing Record 7 of Set 9 | le vauclin
# Processing Record 8 of Set 9 | botou
# Processing Record 9 of Set 9 | sitka
# Processing Record 10 of Set 9 | klyuchi
# Processing Record 11 of Set 9 | phichit
# Processing Record 12 of Set 9 | dunmore east
# Processing Record 13 of Set 9 | orbetello
# Processing Record 14 of Set 9 | tanolong
# Processing Record 15 of Set 9 | igrim
# Processing Record 16 of Set 9 | tomar
# Processing Record 17 of Set 9 | astana
# Processing Record 18 of Set 9 | nome
# Processing Record 19 of Set 9 | luebo
# Processing Record 20 of Set 9 | georgetown
# Processing Record 21 of Set 9 | belaya gora
# Processing Record 22 of Set 9 | xiantao
# Processing Record 23 of Set 9 | micheweni
# Processing Record 24 of Set 9 | haines junction
# Processing Record 25 of Set 9 | pochutla
# Processing Record 26 of Set 9 | roebourne
# Processing Record 27 of Set 9 | yerbogachen
# Processing Record 28 of Set 9 | kahului
# Processing Record 29 of Set 9 | ulagan
# Processing Record 30 of Set 9 | sopur
# Processing Record 31 of Set 9 | arenapolis
# Processing Record 32 of Set 9 | romny
# Processing Record 33 of Set 9 | ust-tsilma
# Processing Record 34 of Set 9 | thohoyandou
# Processing Record 35 of Set 9 | misratah
# Processing Record 36 of Set 9 | quatre cocos
# Processing Record 37 of Set 9 | antalaha
# Processing Record 38 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 38 of Set 9 | borogontsy
# Processing Record 39 of Set 9 | oistins
# Processing Record 40 of Set 9 | lyuban
# Processing Record 41 of Set 9 | zwedru
# Processing Record 42 of Set 9 | chabahar
# Processing Record 43 of Set 9 | deputatskiy
# Processing Record 44 of Set 9 | guisa
# Processing Record 45 of Set 9 | ishigaki
# Processing Record 46 of Set 9 | bani
# Processing Record 47 of Set 9 | nata
# Processing Record 48 of Set 9 | lopatino
# Processing Record 49 of Set 9 | bourail
# Processing Record 50 of Set 9 | coihaique
# Processing Record 1 of Set 10 | katherine
# Processing Record 2 of Set 10 | tiznit
# Processing Record 3 of Set 10 | kroya
# Processing Record 4 of Set 10 | dobrovice
# Processing Record 5 of Set 10 | puerto cabezas
# Processing Record 6 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 6 of Set 10 | vila velha
# Processing Record 7 of Set 10 | upata
# Processing Record 8 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 10 | huilong
# Processing Record 9 of Set 10 | axim
# Processing Record 10 of Set 10 | ketchikan
# Processing Record 11 of Set 10 | chulman
# Processing Record 12 of Set 10 | kulhudhuffushi
# Processing Record 13 of Set 10 | labuhan
# Processing Record 14 of Set 10 | kinkala
# Processing Record 15 of Set 10 | maniitsoq
# Processing Record 16 of Set 10 | torres
# Processing Record 17 of Set 10 | nouadhibou
# Processing Record 18 of Set 10 | camabatela
# Processing Record 19 of Set 10 | gayeri
# Processing Record 20 of Set 10 | stokmarknes
# Processing Record 21 of Set 10 | owando
# Processing Record 22 of Set 10 | saint-augustin
# Processing Record 23 of Set 10 | itoman
# Processing Record 24 of Set 10 | marawi
# Processing Record 25 of Set 10 | dunedin
# Processing Record 26 of Set 10 | blyth
# Processing Record 27 of Set 10 | hue
# Processing Record 28 of Set 10 | pogonsili
# City not found. Skipping...
# Processing Record 28 of Set 10 | montemor-o-novo
# Processing Record 29 of Set 10 | trairi
# Processing Record 30 of Set 10 | aksu
# Processing Record 31 of Set 10 | salamiyah
# Processing Record 32 of Set 10 | mnogovershinnyy
# Processing Record 33 of Set 10 | cuamba
# Processing Record 34 of Set 10 | upernavik
# Processing Record 35 of Set 10 | marolambo
# Processing Record 36 of Set 10 | suclayin
# Processing Record 37 of Set 10 | jarjis
# City not found. Skipping...
# Processing Record 37 of Set 10 | tabas
# Processing Record 38 of Set 10 | puerto del rosario
# Processing Record 39 of Set 10 | dvinskoy
# Processing Record 40 of Set 10 | hovd
# Processing Record 41 of Set 10 | tomatlan
# Processing Record 42 of Set 10 | herat
# Processing Record 43 of Set 10 | nazarovo
# Processing Record 44 of Set 10 | mbandaka
# Processing Record 45 of Set 10 | forssa
# Processing Record 46 of Set 10 | tchaourou
# Processing Record 47 of Set 10 | san vicente
# Processing Record 48 of Set 10 | manturovo
# Processing Record 49 of Set 10 | gorkovskoye
# City not found. Skipping...
# Processing Record 49 of Set 10 | bagan
# Processing Record 50 of Set 10 | ouallam
# Processing Record 1 of Set 11 | katangli
# Processing Record 2 of Set 11 | jiaozuo
# Processing Record 3 of Set 11 | pimentel
# Processing Record 4 of Set 11 | eurajoki
# Processing Record 5 of Set 11 | vila do maio
# Processing Record 6 of Set 11 | inuvik
# Processing Record 7 of Set 11 | kavaratti
# Processing Record 8 of Set 11 | puttur
# Processing Record 9 of Set 11 | huntsville
# Processing Record 10 of Set 11 | richards bay
# Processing Record 11 of Set 11 | qeshm
# Processing Record 12 of Set 11 | sangar
# Processing Record 13 of Set 11 | vanavara
# Processing Record 14 of Set 11 | kenai
# Processing Record 15 of Set 11 | miri
# Processing Record 16 of Set 11 | zharkent
# Processing Record 17 of Set 11 | gizo
# Processing Record 18 of Set 11 | biak
# Processing Record 19 of Set 11 | pingliang
# Processing Record 20 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 11 | garowe
# Processing Record 21 of Set 11 | pasighat
# Processing Record 22 of Set 11 | makakilo city
# Processing Record 23 of Set 11 | alexandria
# Processing Record 24 of Set 11 | pontianak
# Processing Record 25 of Set 11 | juneau
# Processing Record 26 of Set 11 | boulder
# Processing Record 27 of Set 11 | navirai
# Processing Record 28 of Set 11 | zulueta
# Processing Record 29 of Set 11 | suda
# Processing Record 30 of Set 11 | san juan ixcoy
# Processing Record 31 of Set 11 | puerto palomas
# Processing Record 32 of Set 11 | lakhtar
# Processing Record 33 of Set 11 | phonhong
# Processing Record 34 of Set 11 | isiro
# Processing Record 35 of Set 11 | roald
# Processing Record 36 of Set 11 | novyy urengoy
# Processing Record 37 of Set 11 | izhevskoye
# Processing Record 38 of Set 11 | oyama
# Processing Record 39 of Set 11 | barcelos
# Processing Record 40 of Set 11 | itarema
# Processing Record 41 of Set 11 | mauganj
# Processing Record 42 of Set 11 | ayorou
# Processing Record 43 of Set 11 | mpophomeni
# Processing Record 44 of Set 11 | cranbrook
# Processing Record 45 of Set 11 | lang suan
# Processing Record 46 of Set 11 | cozumel
# City not found. Skipping...
# Processing Record 46 of Set 11 | pimampiro
# Processing Record 47 of Set 11 | roznava
# Processing Record 48 of Set 11 | yunjinghong
# City not found. Skipping...

# %%
weatherData = weatherData.dropna(how='any')
weatherData.count()
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
#Store dataframe to a csv file
export_csv = weatherData.to_csv(output_data_file)

# %%
weatherData.head()
# Out:
#               City  Cloudiness Country          Date  Humidity    Lat     Lng  \
# 1            kapaa        90.0      US  1.573579e+09     100.0  22.08 -159.32
# 2  bandar-e lengeh         0.0      IR  1.573579e+09      38.0  26.56   54.88
# 3           avarua        18.0      CK  1.573579e+09      83.0 -21.21 -159.78
# 4     kruisfontein       100.0      ZA  1.573579e+09      85.0 -34.00   24.73
# 5       lavrentiya       100.0      RU  1.573579e+09      91.0  65.58 -170.99
#
#    Max Temp  Wind Speed
# 1    296.15        2.60
# 2    296.15        2.10
# 3    297.15        4.60
# 4    289.68       10.71
# 5    274.37        5.32

# %%
#Getting today's Date https://www.cyberciti.biz/faq/howto-get-current-date-time-in-python/
date = (time.strftime("%m/%d/%Y"))
date
# Out:
# '11/12/2019'

# %% [markdown]
# # Latitude vs. Temperature Plot

# %%
fig, temp = plt.subplots()
temp.plot(weatherData['Lat'], weatherData['Max Temp'], linestyle='none', marker = 'o', markeredgewidth =0.75, markeredgecolor='black')
temp.set_title(f"City Latitude vs. Tempertaure ({date})")
temp.grid()
temp.set_xlabel('Latitude')
temp.set_ylabel('Max Temperature (F)')
plt.show()

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
fig, humi = plt.subplots()
humi.plot(weatherData['Lat'], weatherData['Humidity'], linestyle='none', marker = 'o', markeredgewidth =0.75, markeredgecolor='black')
humi.set_title(f"City Latitude vs. Humidity ({date})")
humi.grid()
humi.set_xlabel('Latitude')
humi.set_ylabel('Humidity (%)')
plt.show()

# %% [markdown]
# # Latitude vs. Cloudiness

# %%
fig, clou = plt.subplots()
clou.plot(weatherData['Lat'], weatherData['Cloudiness'], linestyle='none', marker = 'o', markeredgewidth =0.75, markeredgecolor='black')
clou.set_title(f"City Latitude vs. Cloudiness ({date})")
clou.grid()
clou.set_xlabel('Latitude')
clou.set_ylabel('Cloudiness (%)')
plt.show()

# %% [markdown]
# # Latitude vs. Wind Speed

# %%
fig, wind = plt.subplots()
wind.plot(weatherData['Lat'], weatherData['Wind Speed'], linestyle='none', marker = 'o', markeredgewidth =0.75, markeredgecolor='black')
wind.set_title(f"City Latitude vs. Wind Speed ({date})")
wind.grid()
wind.set_xlabel('Latitude')
wind.set_ylabel('Wind Speed (mph)')
plt.show()
